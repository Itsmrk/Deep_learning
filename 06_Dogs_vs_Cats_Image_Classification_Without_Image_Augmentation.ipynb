# %% [markdown]
# <a href="https://colab.research.google.com/github/Itsmrk/Deep_learning/blob/master/06_Dogs_vs_Cats_Image_Classification_Without_Image_Augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Importing packages**

# %%
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %% [markdown]
# ## **Data Loading**

# %%
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
zip_dir = tf.keras.utils.get_file('cats_and_dogs_filterted.zip', origin=_URL, extract=True)
# Out:
# Downloading data from https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# 68608000/68606236 [==============================] - 1s 0us/step

# %%
#We can list the directories with the following terminal command:
zip_dir_base = os.path.dirname(zip_dir)
# !find $zip_dir_base -type d -print
# Out:
# /root/.keras/datasets
# /root/.keras/datasets/cats_and_dogs_filtered
# /root/.keras/datasets/cats_and_dogs_filtered/validation
# /root/.keras/datasets/cats_and_dogs_filtered/validation/cats
# /root/.keras/datasets/cats_and_dogs_filtered/validation/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/train
# /root/.keras/datasets/cats_and_dogs_filtered/train/cats
# /root/.keras/datasets/cats_and_dogs_filtered/train/dogs

# %%
base_dir = os.path.join(os.path.dirname(zip_dir), 'cats_and_dogs_filtered')
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

# %% [markdown]
# ### **Understanding our data**

# %%
num_cats_tr = len(os.listdir(train_cats_dir))
num_dogs_tr = len(os.listdir(train_dogs_dir))

num_cats_val = len(os.listdir(validation_cats_dir))
num_dogs_val = len(os.listdir(validation_dogs_dir))

total_train = num_cats_tr + num_dogs_tr
total_val = num_cats_val + num_dogs_val

# %%
print("Total Traning Cats : ", num_cats_tr)
print("Total Traning Dogs : ", num_dogs_tr)

print("Total Validation Cats : ", num_cats_val)
print("Total Validation Dogs : ", num_dogs_val)

print("---------")

print("Total Traning Images : ", total_train)
print("Total Validating Images : ", total_val)
# Out:
# Total Traning Cats :  1000
# Total Traning Dogs :  1000
# Total Validation Cats :  500
# Total Validation Dogs :  500
# ---------
# Total Traning Images :  2000
# Total Validating Images :  1000

# %% [markdown]
# ## **Setting Model Parameters**

# %%
BATCH_SIZE = 100
IMG_SHAPE = 150

# %% [markdown]
# ## **Data Preparation**

# %%
train_img_generator = ImageDataGenerator(rescale=1./255)
validation_img_generator = ImageDataGenerator(rescale=1./255)

# %%
train_data_gen = train_img_generator.flow_from_directory(directory = train_dir,
                                                         target_size =(IMG_SHAPE,IMG_SHAPE),
                                                         class_mode = 'binary',
                                                         batch_size = BATCH_SIZE,
                                                         shuffle = True,
                                                         )
# Out:
# Found 2000 images belonging to 2 classes.

# %%
val_data_gen = validation_img_generator.flow_from_directory(directory = validation_dir,
                                                         target_size =(IMG_SHAPE,IMG_SHAPE),
                                                         class_mode = 'binary',
                                                         batch_size = BATCH_SIZE,
                                                         shuffle = True,
                                                         )
# Out:
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# ### **Visualizing Training images**

# %%
sample_training_images, _ = next(train_data_gen)

# %%
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
plotImages(sample_training_images[:5])

# %% [markdown]
# # **Model Creation**

# %% [markdown]
# ## **Define the model**

# %%
model = tf.keras.models.Sequential([
                                    tf.keras.layers.Conv2D(32,(3,3), activation='relu', input_shape = (150,150,3)),
                                    tf.keras.layers.MaxPooling2D(2,2),

                                    tf.keras.layers.Conv2D(64,(3,3), activation='relu'),
                                    tf.keras.layers.MaxPooling2D(2,2),

                                    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
                                    tf.keras.layers.MaxPooling2D(2,2),

                                    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
                                    tf.keras.layers.MaxPooling2D(2,2),

                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(512, activation='relu'),
                                    tf.keras.layers.Dense(2)
])

# %% [markdown]
# ### `Compile the model`

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics =['accuracy'])

# %% [markdown]
# ### Model Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 3,453,634
# Trainable params: 3,453,634
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
EPOCHS = 100
history = model.fit_generator(
    train_data_gen,
    steps_per_epoch = int(np.ceil(total_train/float(BATCH_SIZE))),
    epochs = EPOCHS,
    validation_data = val_data_gen,
    validation_steps = int(np.ceil(total_val/ float(BATCH_SIZE)))
)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 9s 426ms/step - loss: 0.7644 - accuracy: 0.4785 - val_loss: 0.6929 - val_accuracy: 0.5090
# Epoch 2/100
# 20/20 [==============================] - 8s 424ms/step - loss: 0.6920 - accuracy: 0.5275 - val_loss: 0.6894 - val_accuracy: 0.5070
# Epoch 3/100
# 20/20 [==============================] - 8s 425ms/step - loss: 0.6862 - accuracy: 0.5495 - val_loss: 0.6715 - val_accuracy: 0.6180
# Epoch 4/100
# 20/20 [==============================] - 8s 422ms/step - loss: 0.6558 - accuracy: 0.6285 - val_loss: 0.6252 - val_accuracy: 0.6680
# Epoch 5/100
# 20/20 [==============================] - 8s 419ms/step - loss: 0.6340 - accuracy: 0.6255 - val_loss: 0.6168 - val_accuracy: 0.6680
# Epoch 6/100
# 20/20 [==============================] - 8s 424ms/step - loss: 0.6169 - accuracy: 0.6420 - val_loss: 0.6504 - val_accuracy: 0.5860
# Epoch 7/100
# 20/20 [==============================] - 8s 421ms/step - loss: 0.5796 - accuracy: 0.6925 - val_loss: 0.6088 - val_accuracy: 0.6710
# Epoch 8/100
# 20/20 [==============================] - 9s 427ms/step - loss: 0.5160 - accuracy: 0.7425 - val_loss: 0.5555 - val_accuracy: 0.7210
# Epoch 9/100
# 20/20 [==============================] - 9s 425ms/step - loss: 0.4826 - accuracy: 0.7705 - val_loss: 0.5783 - val_accuracy: 0.7060
# Epoch 10/100
# 20/20 [==============================] - 8s 424ms/step - loss: 0.4545 - accuracy: 0.7770 - val_loss: 0.6518 - val_accuracy: 0.6840
# Epoch 11/100
# 20/20 [==============================] - 8s 422ms/step - loss: 0.4033 - accuracy: 0.8225 - val_loss: 0.6055 - val_accuracy: 0.7350
# Epoch 12/100
# 20/20 [==============================] - 8s 419ms/step - loss: 0.3503 - accuracy: 0.8475 - val_loss: 0.6144 - val_accuracy: 0.7140
# Epoch 13/100
# 20/20 [==============================] - 8s 421ms/step - loss: 0.2613 - accuracy: 0.8900 - val_loss: 0.6894 - val_accuracy: 0.7210
# Epoch 14/100
# 20/20 [==============================] - 8s 423ms/step - loss: 0.2236 - accuracy: 0.9090 - val_loss: 0.6723 - val_accuracy: 0.7410
# Epoch 15/100
# 20/20 [==============================] - 8s 421ms/step - loss: 0.1602 - accuracy: 0.9400 - val_loss: 0.9238 - val_accuracy: 0.7270
# Epoch 16/100
# 20/20 [==============================] - 8s 414ms/step - loss: 0.1333 - accuracy: 0.9495 - val_loss: 0.9699 - val_accuracy: 0.7080
# Epoch 17/100
# 20/20 [==============================] - 8s 419ms/step - loss: 0.0976 - accuracy: 0.9645 - val_loss: 1.0027 - val_accuracy: 0.7530
# Epoch 18/100
# 20/20 [==============================] - 8s 419ms/step - loss: 0.0621 - accuracy: 0.9810 - val_loss: 1.1365 - val_accuracy: 0.7320
# Epoch 19/100
# 20/20 [==============================] - 8s 421ms/step - loss: 0.0501 - accuracy: 0.9825 - val_loss: 1.2613 - val_accuracy: 0.7290
# Epoch 20/100
# 20/20 [==============================] - 8s 416ms/step - loss: 0.0338 - accuracy: 0.9905 - val_loss: 1.3564 - val_accuracy: 0.7520
# Epoch 21/100
# 20/20 [==============================] - 8s 419ms/step - loss: 0.0238 - accuracy: 0.9960 - val_loss: 1.3605 - val_accuracy: 0.7290
# Epoch 22/100
# 20/20 [==============================] - 8s 421ms/step - loss: 0.0164 - accuracy: 0.9955 - val_loss: 1.4047 - val_accuracy: 0.7430
# Epoch 23/100
# 20/20 [==============================] - 8s 421ms/step - loss: 0.0122 - accuracy: 0.9965 - val_loss: 1.5645 - val_accuracy: 0.7530
# Epoch 24/100
# 20/20 [==============================] - 8s 416ms/step - loss: 0.0072 - accuracy: 0.9990 - val_loss: 1.5938 - val_accuracy: 0.7530
# Epoch 25/100
# 20/20 [==============================] - 8s 421ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.8763 - val_accuracy: 0.7460
# Epoch 26/100
# 20/20 [==============================] - 8s 420ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.7105 - val_accuracy: 0.7480
# Epoch 27/100
# 20/20 [==============================] - 8s 417ms/step - loss: 6.9388e-04 - accuracy: 1.0000 - val_loss: 2.0005 - val_accuracy: 0.7340
# Epoch 28/100
# 20/20 [==============================] - 8s 424ms/step - loss: 5.3338e-04 - accuracy: 1.0000 - val_loss: 1.8761 - val_accuracy: 0.7410
# Epoch 29/100
# 20/20 [==============================] - 8s 422ms/step - loss: 4.6901e-04 - accuracy: 1.0000 - val_loss: 1.7940 - val_accuracy: 0.7370
# Epoch 30/100
# 20/20 [==============================] - 8s 418ms/step - loss: 3.3804e-04 - accuracy: 1.0000 - val_loss: 1.9790 - val_accuracy: 0.7380
# Epoch 31/100
# 20/20 [==============================] - 8s 417ms/step - loss: 3.0409e-04 - accuracy: 1.0000 - val_loss: 1.9383 - val_accuracy: 0.7410
# Epoch 32/100
# 20/20 [==============================] - 8s 419ms/step - loss: 2.5500e-04 - accuracy: 1.0000 - val_loss: 1.9698 - val_accuracy: 0.7330
# Epoch 33/100
# 20/20 [==============================] - 8s 421ms/step - loss: 2.2267e-04 - accuracy: 1.0000 - val_loss: 2.0144 - val_accuracy: 0.7380
# Epoch 34/100
# 20/20 [==============================] - 8s 423ms/step - loss: 2.1013e-04 - accuracy: 1.0000 - val_loss: 2.0611 - val_accuracy: 0.7380
# Epoch 35/100
# 20/20 [==============================] - 9s 426ms/step - loss: 1.7423e-04 - accuracy: 1.0000 - val_loss: 1.8592 - val_accuracy: 0.7690
# Epoch 36/100
# 20/20 [==============================] - 8s 418ms/step - loss: 1.6783e-04 - accuracy: 1.0000 - val_loss: 2.0159 - val_accuracy: 0.7350
# Epoch 37/100
# 20/20 [==============================] - 8s 424ms/step - loss: 1.5495e-04 - accuracy: 1.0000 - val_loss: 2.2316 - val_accuracy: 0.7240
# Epoch 38/100
# 20/20 [==============================] - 8s 421ms/step - loss: 1.4416e-04 - accuracy: 1.0000 - val_loss: 1.9304 - val_accuracy: 0.7620
# Epoch 39/100
# 20/20 [==============================] - 8s 418ms/step - loss: 1.2648e-04 - accuracy: 1.0000 - val_loss: 2.0700 - val_accuracy: 0.7400
# Epoch 40/100
# 20/20 [==============================] - 8s 419ms/step - loss: 1.2572e-04 - accuracy: 1.0000 - val_loss: 2.1224 - val_accuracy: 0.7390
# Epoch 41/100
# 20/20 [==============================] - 8s 416ms/step - loss: 1.1027e-04 - accuracy: 1.0000 - val_loss: 2.0901 - val_accuracy: 0.7430
# Epoch 42/100
# 20/20 [==============================] - 8s 417ms/step - loss: 1.0062e-04 - accuracy: 1.0000 - val_loss: 2.1935 - val_accuracy: 0.7410
# Epoch 43/100
# 20/20 [==============================] - 8s 416ms/step - loss: 1.0055e-04 - accuracy: 1.0000 - val_loss: 1.9632 - val_accuracy: 0.7470
# Epoch 44/100
# 20/20 [==============================] - 8s 416ms/step - loss: 9.5958e-05 - accuracy: 1.0000 - val_loss: 2.0801 - val_accuracy: 0.7370
# Epoch 45/100
# 20/20 [==============================] - 8s 422ms/step - loss: 8.1847e-05 - accuracy: 1.0000 - val_loss: 2.1854 - val_accuracy: 0.7440
# Epoch 46/100
# 20/20 [==============================] - 8s 423ms/step - loss: 7.9576e-05 - accuracy: 1.0000 - val_loss: 2.2041 - val_accuracy: 0.7340
# Epoch 47/100
# 20/20 [==============================] - 8s 421ms/step - loss: 7.7265e-05 - accuracy: 1.0000 - val_loss: 2.2227 - val_accuracy: 0.7350
# Epoch 48/100
# 20/20 [==============================] - 8s 416ms/step - loss: 7.3261e-05 - accuracy: 1.0000 - val_loss: 2.1388 - val_accuracy: 0.7550
# Epoch 49/100
# 20/20 [==============================] - 8s 415ms/step - loss: 6.5138e-05 - accuracy: 1.0000 - val_loss: 2.1239 - val_accuracy: 0.7370
# Epoch 50/100
# 20/20 [==============================] - 8s 417ms/step - loss: 6.5332e-05 - accuracy: 1.0000 - val_loss: 2.1931 - val_accuracy: 0.7510
# Epoch 51/100
# 20/20 [==============================] - 8s 416ms/step - loss: 6.1982e-05 - accuracy: 1.0000 - val_loss: 2.1911 - val_accuracy: 0.7420
# Epoch 52/100
# 20/20 [==============================] - 8s 417ms/step - loss: 5.6294e-05 - accuracy: 1.0000 - val_loss: 2.2960 - val_accuracy: 0.7380
# Epoch 53/100
# 20/20 [==============================] - 8s 416ms/step - loss: 5.7790e-05 - accuracy: 1.0000 - val_loss: 2.1108 - val_accuracy: 0.7480
# Epoch 54/100
# 20/20 [==============================] - 8s 417ms/step - loss: 4.9044e-05 - accuracy: 1.0000 - val_loss: 2.1172 - val_accuracy: 0.7500
# Epoch 55/100
# 20/20 [==============================] - 8s 416ms/step - loss: 4.9485e-05 - accuracy: 1.0000 - val_loss: 2.2812 - val_accuracy: 0.7390
# Epoch 56/100
# 20/20 [==============================] - 8s 422ms/step - loss: 4.7908e-05 - accuracy: 1.0000 - val_loss: 2.1201 - val_accuracy: 0.7560
# Epoch 57/100
# 20/20 [==============================] - 8s 415ms/step - loss: 4.5618e-05 - accuracy: 1.0000 - val_loss: 2.2424 - val_accuracy: 0.7380
# Epoch 58/100
# 20/20 [==============================] - 8s 419ms/step - loss: 4.3318e-05 - accuracy: 1.0000 - val_loss: 2.1343 - val_accuracy: 0.7430
# Epoch 59/100
# 20/20 [==============================] - 8s 417ms/step - loss: 4.0859e-05 - accuracy: 1.0000 - val_loss: 2.2061 - val_accuracy: 0.7540
# Epoch 60/100
# 20/20 [==============================] - 8s 422ms/step - loss: 3.8392e-05 - accuracy: 1.0000 - val_loss: 2.3214 - val_accuracy: 0.7360
# Epoch 61/100
# 20/20 [==============================] - 8s 417ms/step - loss: 3.7949e-05 - accuracy: 1.0000 - val_loss: 2.2716 - val_accuracy: 0.7440
# Epoch 62/100
# 20/20 [==============================] - 8s 420ms/step - loss: 3.5197e-05 - accuracy: 1.0000 - val_loss: 2.3758 - val_accuracy: 0.7420
# Epoch 63/100
# 20/20 [==============================] - 8s 416ms/step - loss: 3.5101e-05 - accuracy: 1.0000 - val_loss: 2.2346 - val_accuracy: 0.7360
# Epoch 64/100
# 20/20 [==============================] - 8s 418ms/step - loss: 3.2915e-05 - accuracy: 1.0000 - val_loss: 2.3384 - val_accuracy: 0.7470
# Epoch 65/100
# 20/20 [==============================] - 8s 418ms/step - loss: 3.1265e-05 - accuracy: 1.0000 - val_loss: 2.3603 - val_accuracy: 0.7400
# Epoch 66/100
# 20/20 [==============================] - 8s 420ms/step - loss: 3.0625e-05 - accuracy: 1.0000 - val_loss: 2.1456 - val_accuracy: 0.7460
# Epoch 67/100
# 20/20 [==============================] - 8s 417ms/step - loss: 2.9129e-05 - accuracy: 1.0000 - val_loss: 2.6820 - val_accuracy: 0.7230
# Epoch 68/100
# 20/20 [==============================] - 8s 418ms/step - loss: 2.8291e-05 - accuracy: 1.0000 - val_loss: 2.1717 - val_accuracy: 0.7570
# Epoch 69/100
# 20/20 [==============================] - 8s 418ms/step - loss: 2.6679e-05 - accuracy: 1.0000 - val_loss: 2.3007 - val_accuracy: 0.7430
# Epoch 70/100
# 20/20 [==============================] - 8s 415ms/step - loss: 2.6321e-05 - accuracy: 1.0000 - val_loss: 2.2450 - val_accuracy: 0.7490
# Epoch 71/100
# 20/20 [==============================] - 8s 424ms/step - loss: 2.5090e-05 - accuracy: 1.0000 - val_loss: 2.3340 - val_accuracy: 0.7440
# Epoch 72/100
# 20/20 [==============================] - 8s 419ms/step - loss: 2.4306e-05 - accuracy: 1.0000 - val_loss: 2.4685 - val_accuracy: 0.7400
# Epoch 73/100
# 20/20 [==============================] - 8s 418ms/step - loss: 2.3248e-05 - accuracy: 1.0000 - val_loss: 2.3733 - val_accuracy: 0.7420
# Epoch 74/100
# 20/20 [==============================] - 8s 415ms/step - loss: 2.2462e-05 - accuracy: 1.0000 - val_loss: 2.3719 - val_accuracy: 0.7360
# Epoch 75/100
# 20/20 [==============================] - 8s 423ms/step - loss: 2.1565e-05 - accuracy: 1.0000 - val_loss: 2.2413 - val_accuracy: 0.7500
# Epoch 76/100
# 20/20 [==============================] - 8s 416ms/step - loss: 2.0864e-05 - accuracy: 1.0000 - val_loss: 2.3833 - val_accuracy: 0.7420
# Epoch 77/100
# 20/20 [==============================] - 8s 420ms/step - loss: 2.0973e-05 - accuracy: 1.0000 - val_loss: 2.4534 - val_accuracy: 0.7410
# Epoch 78/100
# 20/20 [==============================] - 8s 416ms/step - loss: 1.9328e-05 - accuracy: 1.0000 - val_loss: 2.3660 - val_accuracy: 0.7460
# Epoch 79/100
# 20/20 [==============================] - 8s 415ms/step - loss: 1.8950e-05 - accuracy: 1.0000 - val_loss: 2.2970 - val_accuracy: 0.7390
# Epoch 80/100
# 20/20 [==============================] - 8s 416ms/step - loss: 1.8345e-05 - accuracy: 1.0000 - val_loss: 2.3823 - val_accuracy: 0.7540
# Epoch 81/100
# 20/20 [==============================] - 8s 422ms/step - loss: 1.7158e-05 - accuracy: 1.0000 - val_loss: 2.3912 - val_accuracy: 0.7400
# Epoch 82/100
# 20/20 [==============================] - 8s 416ms/step - loss: 1.6755e-05 - accuracy: 1.0000 - val_loss: 2.4032 - val_accuracy: 0.7380
# Epoch 83/100
# 20/20 [==============================] - 8s 421ms/step - loss: 1.6676e-05 - accuracy: 1.0000 - val_loss: 2.5241 - val_accuracy: 0.7380
# Epoch 84/100
# 20/20 [==============================] - 8s 416ms/step - loss: 1.5852e-05 - accuracy: 1.0000 - val_loss: 2.2596 - val_accuracy: 0.7350
# Epoch 85/100
# 20/20 [==============================] - 8s 424ms/step - loss: 1.5080e-05 - accuracy: 1.0000 - val_loss: 2.5409 - val_accuracy: 0.7440
# Epoch 86/100
# 20/20 [==============================] - 8s 418ms/step - loss: 1.5109e-05 - accuracy: 1.0000 - val_loss: 2.4516 - val_accuracy: 0.7460
# Epoch 87/100
# 20/20 [==============================] - 8s 419ms/step - loss: 1.4682e-05 - accuracy: 1.0000 - val_loss: 2.2210 - val_accuracy: 0.7560
# Epoch 88/100
# 20/20 [==============================] - 8s 420ms/step - loss: 1.3739e-05 - accuracy: 1.0000 - val_loss: 2.5856 - val_accuracy: 0.7280
# Epoch 89/100
# 20/20 [==============================] - 8s 419ms/step - loss: 1.3988e-05 - accuracy: 1.0000 - val_loss: 2.3962 - val_accuracy: 0.7510
# Epoch 90/100
# 20/20 [==============================] - 8s 420ms/step - loss: 1.2925e-05 - accuracy: 1.0000 - val_loss: 2.3980 - val_accuracy: 0.7390
# Epoch 91/100
# 20/20 [==============================] - 8s 419ms/step - loss: 1.2946e-05 - accuracy: 1.0000 - val_loss: 2.4411 - val_accuracy: 0.7450
# Epoch 92/100
# 20/20 [==============================] - 8s 420ms/step - loss: 1.2638e-05 - accuracy: 1.0000 - val_loss: 2.5042 - val_accuracy: 0.7420
# Epoch 93/100
# 20/20 [==============================] - 8s 416ms/step - loss: 1.2148e-05 - accuracy: 1.0000 - val_loss: 2.4856 - val_accuracy: 0.7470
# Epoch 94/100
# 20/20 [==============================] - 8s 422ms/step - loss: 1.1692e-05 - accuracy: 1.0000 - val_loss: 2.3201 - val_accuracy: 0.7400
# Epoch 95/100
# 20/20 [==============================] - 8s 419ms/step - loss: 1.1705e-05 - accuracy: 1.0000 - val_loss: 2.4709 - val_accuracy: 0.7550
# Epoch 96/100
# 20/20 [==============================] - 8s 420ms/step - loss: 1.1084e-05 - accuracy: 1.0000 - val_loss: 2.4781 - val_accuracy: 0.7360
# Epoch 97/100
# 20/20 [==============================] - 8s 417ms/step - loss: 1.1428e-05 - accuracy: 1.0000 - val_loss: 2.6405 - val_accuracy: 0.7260
# Epoch 98/100
# 20/20 [==============================] - 8s 416ms/step - loss: 1.0051e-05 - accuracy: 1.0000 - val_loss: 2.3532 - val_accuracy: 0.7650
# Epoch 99/100
# 20/20 [==============================] - 8s 421ms/step - loss: 1.0334e-05 - accuracy: 1.0000 - val_loss: 2.6624 - val_accuracy: 0.7320
# Epoch 100/100
# 20/20 [==============================] - 8s 416ms/step - loss: 9.7570e-06 - accuracy: 1.0000 - val_loss: 2.5002 - val_accuracy: 0.7450

# %% [markdown]
# ### Visualizing results of the training![alt text](https://)

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range, acc ,label='Traning Accuracy')
plt.plot(epochs_range, val_acc, label= 'Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Traning & Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
#plt.savefig('./foo.png')
plt.show()
